# %%
import plotly as py
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading the data

# %%
data = pd.read_csv("../data/data.csv")

# %%
data.head()
# Out:
#                              salary          education            crawled_at  \
# 0            $17.23 - $22.00 / hour  Bachelor's Degree  05/05/2021, 03:01:49
# 1            $19.00 - $26.00 / hour    Graduate Degree  05/05/2021, 03:01:50
# 2  $106,250.00 - $125,000.00 / year  Bachelor's Degree  05/05/2021, 03:01:50
# 3                               NaN        High School  05/05/2021, 03:01:50
# 4   $85,000.00 - $120,000.00 / year      4 Year Degree  05/05/2021, 03:01:50
#
#                                          description  \
# 0  Job Description\r\nTo implement the Head Start...
# 1  Job Description\r\nYou have the magic. We have...
# 2  Job Description\r\nWe are looking for a CRM de...
# 3  Job Description\r\n\r\nBriggs Dodge Ram Fiat i...
# 4  Job Description\r\n HARLINGEN, TX- RIO GRANDE ...
#
#                                    title  \
# 0                     Head Start Teacher
# 1  Teacher of English for Online Groups!
# 2                    CRM / PHP Developer
# ...

# %%
data = data.iloc[:, :19]

# %%
data.drop("Unnamed: 7", axis=1, inplace=True)

# %%
data.head()
# Out:
#                              salary          education            crawled_at  \
# 0            $17.23 - $22.00 / hour  Bachelor's Degree  05/05/2021, 03:01:49
# 1            $19.00 - $26.00 / hour    Graduate Degree  05/05/2021, 03:01:50
# 2  $106,250.00 - $125,000.00 / year  Bachelor's Degree  05/05/2021, 03:01:50
# 3                               NaN        High School  05/05/2021, 03:01:50
# 4   $85,000.00 - $120,000.00 / year      4 Year Degree  05/05/2021, 03:01:50
#
#                                          description  \
# 0  Job Description\r\nTo implement the Head Start...
# 1  Job Description\r\nYou have the magic. We have...
# 2  Job Description\r\nWe are looking for a CRM de...
# 3  Job Description\r\n\r\nBriggs Dodge Ram Fiat i...
# 4  Job Description\r\n HARLINGEN, TX- RIO GRANDE ...
#
#                                    title  \
# 0                     Head Start Teacher
# 1  Teacher of English for Online Groups!
# 2                    CRM / PHP Developer
# ...

# %%
data_df = data[["salary", "education", "experience", "company", "locality", "region", "employment_type", "title"]]

# %%
data_df.describe()
# Out:
#        salary    education               experience company locality region  \
# count    3043         6187                     5662   10494    10487  10492
# unique   1133           36                       78    1896     3122     65
# top       DOE  High School  No experience required.  Amazon  Atlanta     TX
# freq      167         3024                     1275     635      179    851
#
#        employment_type                            title
# count            10494                            10520
# unique              10                             6366
# top          FULL_TIME  CUSTOMER SERVICE REPRESENTATIVE
# freq              8814                              205
